# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def round_str(s,goal):
    return goal in (s*2)
round_str('abcde','cdeab')
# Out:
# True

# %%
round_str('abcde','abced')
# Out:
# False
